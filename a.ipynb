        [55, 0.33568498, 0.9989624, 1.0],
        [56, 0.33589995, 0.9990845, 1.0],
        [57, 0.33562845, 0.99853516, 1.0],
        [58, 0.3354025, 0.99853516, 1.0],
        [59, 0.335818, 0.99902344, 1.0],
        [60, 0.33565432, 0.9991455, 1.0],
        [61, 0.33565295, 0.9984131, 1.0],
        [62, 0.33560625, 0.99884033, 1.0],
        [63, 0.33542347, 0.99884033, 1.0],
        [64, 0.3355391, 0.9992676, 1.0],
        [65, 0.3354714, 0.99902344, 1.0],
        [66, 0.33536458, 0.9987793, 1.0],
        [67, 0.33548895, 0.99853516, 1.0],
        [68, 0.3357725, 0.9991455, 1.0],
        [69, 0.3355416, 0.9990845, 1.0],
        [70, 0.33561915, 0.9992676, 1.0],
        [71, 0.33539575, 0.9987793, 1.0],
        [72, 0.33540443, 0.9984741, 1.0],
        [73, 0.33529195, 0.9984741, 1.0],
        [74, 0.335465, 0.9984131, 1.0],
        [75, 0.33569282, 0.9986572, 1.0],
        [76, 0.33544832, 0.9990845, 1.0],
        [77, 0.33566266, 0.99890137, 1.0],
        [78, 0.3355888, 0.9981079, 1.0],
        [79, 0.3354771, 0.9985962, 1.0],
        [80, 0.33583933, 0.9986572, 1.0],
        [81, 0.33533686, 0.9987793, 1.0],
        [82, 0.33525178, 0.9984741, 1.0],
        [83, 0.33549476, 0.9990845, 1.0],
        [84, 0.33535013, 0.99871826, 1.0],
        [85, 0.33598527, 0.9987793, 1.0],
        [86, 0.33576047, 0.99890137, 1.0],
        [87, 0.33570555, 0.99920654, 1.0],
        [88, 0.33574665, 0.9986572, 1.0],
        [89, 0.335198, 0.9986572, 1.0],
        [90, 0.3355615, 0.9990845, 1.0],
        [91, 0.3355533, 0.9987793, 1.0],
        [92, 0.33554298, 0.99920654, 1.0],
        [93, 0.3357709, 0.9985962, 1.0],
        [94, 0.3354478, 0.99853516, 1.0],
        [95, 0.33535755, 0.99884033, 1.0],
        [96, 0.33552504, 0.9985962, 1.0],
        [97, 0.33540663, 0.9990845, 1.0],
        [98, 0.33557987, 0.9989624, 1.0],
        [99, 0.33545196, 0.99902344, 1.0]
]

# %%
import numpy as np
data = np.array(data)

# %%
np.mean(data[:,2])
# Out:
# 0.9987988295

# %%
np.mean(data[:,3])
# Out:
# 1.0

# %%
import pickle, os
filelist = os.listdir('data/net/eval/')
zero = one = 0
for filename in filelist:
    file = open('data/net/eval/'+filename, 'rb')
    data = pickle.load(file)
    file.close()
    one += np.sum(data[:,2])
    zero += (len(data) - np.sum(data[:,2]))

# %%
zero
# Out:
# 4291218

# %%
one
# Out:
# 5422
